# %%
import pandas as pd
from util import DataFile

# %%
path = "data/csv/team/" #팀별 데이터가 있는 디렉토리
data = DataFile(path).load_csv()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 97/97 [00:02<00:00, 37.44it/s]

# %%
data.head(n=5)
# Out:
#    Unnamed: 0   id         name  firstname  lastname   age  birth_date  \
# 0           0  416      S. Rudy  Sebastian      Rudy  32.0  1990-02-28
# 1           1  416      S. Rudy  Sebastian      Rudy  32.0  1990-02-28
# 2           2  702   O. Baumann     Oliver   Baumann  32.0  1990-06-02
# 3           3  702   O. Baumann     Oliver   Baumann  32.0  1990-06-02
# 4           4  705  E. Bičakčić      Ermin  Bičakčić  32.0  1990-01-24
#
#               birth_place           birth_country             nationality  \
# 0  Villingen-Schwenningen                 Germany                 Germany
# 1  Villingen-Schwenningen                 Germany                 Germany
# 2                Breisach                 Germany                 Germany
# 3                Breisach                 Germany                 Germany
# 4                 Zvornik  Bosnia and Herzegovina  Bosnia and Herzegovina
#
#    ... fouls_drawn fouls_committed  cards_yellow cards_yellowred  cards_red  \
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'firstname', 'lastname', 'age',
#        'birth_date', 'birth_place', 'birth_country', 'nationality', 'height',
#        'weight', 'injured', 'photo', 'team_id', 'team_name', 'team_logo',
#        'league_id', 'league_name', 'league_country', 'league_logo',
#        'league_flag', 'league_season', 'games_appearences', 'games_lineups',
#        'games_minutes', 'games_number', 'games_position', 'games_rating',
#        'games_captain', 'substitutes_in', 'substitutes_out',
#        'substitutes_bench', 'shots_total', 'shots_on', 'goals_total',
#        'goals_conceded', 'goals_assists', 'goals_saves', 'passes_total',
#        'passes_key', 'passes_accuracy', 'tackles_total', 'tackles_blocks',
#        'tackles_interceptions', 'duels_total', 'duels_won',
#        'dribbles_attempts', 'dribbles_success', 'dribbles_past', 'fouls_drawn',
#        'fouls_committed', 'cards_yellow', 'cards_yellowred', 'cards_red',
# ...

# %%
# Out:
# <bound method NDFrame.head of     Unnamed: 0      id          name  firstname     lastname   age  \
# 0            0     416       S. Rudy  Sebastian         Rudy  32.0
# 1            1     416       S. Rudy  Sebastian         Rudy  32.0
# 2            2     702    O. Baumann     Oliver      Baumann  32.0
# 3            3     702    O. Baumann     Oliver      Baumann  32.0
# 4            4     705   E. Bičakčić      Ermin     Bičakčić  32.0
# ..         ...     ...           ...        ...          ...   ...
# 49          49  280687    Hugo Bueno       Hugo  Bueno López  20.0
# 50          50  284237  D. Lembikisa     Dexter    Lembikisa  19.0
# 51          51  284237  D. Lembikisa     Dexter    Lembikisa  19.0
# 52          52  288115     J. Storer      James       Storer   NaN
# 53          53  288115     J. Storer      James       Storer   NaN
#
#     birth_date             birth_place           birth_country  \
# 0   1990-02-28  Villingen-Schwenningen                 Germany
# ...
